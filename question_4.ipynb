# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Conv2D , MaxPooling2D
from keras.layers import Dense, Dropout , Flatten
from keras import backend as K

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print('x_train: ', x_train.shape)
# Out:
# x_train:  (50000, 32, 32, 3)

# %%
K = len(np.unique(y_train)) # Classes
Ntr = x_train.shape[0]

Nte = x_test.shape[0]
Din = 3072 # CIFAR10    #32 x 32 x 3
# Din = 784 # MINIST


# Normalize pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)
x_train = x_train - mean_image
x_test = x_test - mean_image

print('y_train: ', y_train.shape)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=K)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)
print('y_train: ', y_train.shape)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# y_train:  (50000, 1)
# y_train:  (50000, 10)

# %%
model = Sequential()

#First Conv2D layer
model.add(Conv2D(filters=32 , kernel_size=(3,3) , activation = 'relu' , input_shape = (32,32,3) ))
model.add(MaxPooling2D(pool_size= (2,2) ))

model.add(Conv2D(64, kernel_size = (3,3) , activation = 'relu'))
model.add(MaxPooling2D(pool_size= (2,2)))

model.add(Conv2D(64 , kernel_size = (3,3) , activation = 'relu'))
model.add(MaxPooling2D(pool_size= (2,2)))

model.add(Flatten())
model.add(Dense(64 , activation = 'relu'))

model.add(Dense(10 , activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                16448
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 73,418
# Trainable params: 73,418
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.01, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train, epochs=50 , batch_size=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 47s 46ms/step - loss: 1.9073 - accuracy: 0.2982 - val_loss: 1.3324 - val_accuracy: 0.5157
# Epoch 2/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 1.2814 - accuracy: 0.5382 - val_loss: 1.1136 - val_accuracy: 0.6068
# Epoch 3/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 1.0756 - accuracy: 0.6206 - val_loss: 1.0340 - val_accuracy: 0.6413
# Epoch 4/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.9366 - accuracy: 0.6701 - val_loss: 0.9274 - val_accuracy: 0.6798
# Epoch 5/50
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.8402 - accuracy: 0.7090 - val_loss: 0.9266 - val_accuracy: 0.6884
# Epoch 6/50
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.7560 - accuracy: 0.7361 - val_loss: 0.8837 - val_accuracy: 0.6956
# Epoch 7/50
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.7012 - accuracy: 0.7561 - val_loss: 0.8989 - val_accuracy: 0.6990
# Epoch 8/50
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.6538 - accuracy: 0.7681 - val_loss: 0.8324 - val_accuracy: 0.7175
# Epoch 9/50
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.6142 - accuracy: 0.7831 - val_loss: 0.8642 - val_accuracy: 0.7118
# Epoch 10/50
# 1000/1000 [==============================] - 40s 40ms/step - loss: 0.5670 - accuracy: 0.7994 - val_loss: 0.8574 - val_accuracy: 0.7192
# Epoch 11/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.5234 - accuracy: 0.8142 - val_loss: 0.8275 - val_accuracy: 0.7266
# Epoch 12/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.4922 - accuracy: 0.8289 - val_loss: 0.8611 - val_accuracy: 0.7241
# Epoch 13/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.4581 - accuracy: 0.8375 - val_loss: 0.8857 - val_accuracy: 0.7242
# Epoch 14/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.4290 - accuracy: 0.8461 - val_loss: 0.9375 - val_accuracy: 0.7231
# Epoch 15/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.4075 - accuracy: 0.8553 - val_loss: 0.9336 - val_accuracy: 0.7166
# Epoch 16/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.3869 - accuracy: 0.8607 - val_loss: 1.0115 - val_accuracy: 0.7166
# Epoch 17/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.3682 - accuracy: 0.8670 - val_loss: 1.0701 - val_accuracy: 0.7053
# Epoch 18/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.3512 - accuracy: 0.8744 - val_loss: 1.0246 - val_accuracy: 0.7096
# Epoch 19/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.3283 - accuracy: 0.8809 - val_loss: 1.0657 - val_accuracy: 0.7145
# Epoch 20/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.3098 - accuracy: 0.8908 - val_loss: 1.0827 - val_accuracy: 0.7105
# Epoch 21/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.2953 - accuracy: 0.8942 - val_loss: 1.1218 - val_accuracy: 0.7136
# Epoch 22/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2879 - accuracy: 0.8973 - val_loss: 1.1326 - val_accuracy: 0.7101
# Epoch 23/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2836 - accuracy: 0.8984 - val_loss: 1.1919 - val_accuracy: 0.7138
# Epoch 24/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2708 - accuracy: 0.9003 - val_loss: 1.1970 - val_accuracy: 0.7029
# Epoch 25/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2557 - accuracy: 0.9101 - val_loss: 1.3133 - val_accuracy: 0.7044
# Epoch 26/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2640 - accuracy: 0.9043 - val_loss: 1.2652 - val_accuracy: 0.7026
# Epoch 27/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2556 - accuracy: 0.9094 - val_loss: 1.3766 - val_accuracy: 0.7008
# Epoch 28/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2421 - accuracy: 0.9103 - val_loss: 1.3838 - val_accuracy: 0.7096
# Epoch 29/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2170 - accuracy: 0.9206 - val_loss: 1.3963 - val_accuracy: 0.7017
# Epoch 30/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2290 - accuracy: 0.9182 - val_loss: 1.4929 - val_accuracy: 0.6967
# Epoch 31/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2251 - accuracy: 0.9187 - val_loss: 1.4326 - val_accuracy: 0.7101
# Epoch 32/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.2160 - accuracy: 0.9226 - val_loss: 1.4606 - val_accuracy: 0.7029
# Epoch 33/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2160 - accuracy: 0.9233 - val_loss: 1.5344 - val_accuracy: 0.6945
# Epoch 34/50
# 1000/1000 [==============================] - 44s 44ms/step - loss: 0.2174 - accuracy: 0.9223 - val_loss: 1.5828 - val_accuracy: 0.6933
# Epoch 35/50
# 1000/1000 [==============================] - 43s 43ms/step - loss: 0.1992 - accuracy: 0.9305 - val_loss: 1.4999 - val_accuracy: 0.7077
# Epoch 36/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1966 - accuracy: 0.9307 - val_loss: 1.6382 - val_accuracy: 0.7000
# Epoch 37/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.2015 - accuracy: 0.9278 - val_loss: 1.5641 - val_accuracy: 0.7043
# Epoch 38/50
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.2013 - accuracy: 0.9298 - val_loss: 1.6551 - val_accuracy: 0.7063
# Epoch 39/50
# 1000/1000 [==============================] - 37s 37ms/step - loss: 0.1858 - accuracy: 0.9340 - val_loss: 1.5667 - val_accuracy: 0.7067
# Epoch 40/50
# 1000/1000 [==============================] - 45s 45ms/step - loss: 0.1834 - accuracy: 0.9348 - val_loss: 1.6136 - val_accuracy: 0.7001
# Epoch 41/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1938 - accuracy: 0.9323 - val_loss: 1.6384 - val_accuracy: 0.7102
# Epoch 42/50
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.1997 - accuracy: 0.9298 - val_loss: 1.6810 - val_accuracy: 0.7048
# Epoch 43/50
# 1000/1000 [==============================] - 39s 39ms/step - loss: 0.1929 - accuracy: 0.9334 - val_loss: 1.6998 - val_accuracy: 0.7024
# Epoch 44/50
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1975 - accuracy: 0.9305 - val_loss: 1.7776 - val_accuracy: 0.6978
# Epoch 45/50
# 1000/1000 [==============================] - 42s 42ms/step - loss: 0.1856 - accuracy: 0.9347 - val_loss: 1.7643 - val_accuracy: 0.6948
# Epoch 46/50
# 1000/1000 [==============================] - 41s 41ms/step - loss: 0.1823 - accuracy: 0.9380 - val_loss: 1.8124 - val_accuracy: 0.6992
# Epoch 47/50
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.1815 - accuracy: 0.9391 - val_loss: 1.8313 - val_accuracy: 0.6970
# Epoch 48/50
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1974 - accuracy: 0.9322 - val_loss: 1.8235 - val_accuracy: 0.6909
# Epoch 49/50
# 1000/1000 [==============================] - 38s 38ms/step - loss: 0.1828 - accuracy: 0.9363 - val_loss: 1.8658 - val_accuracy: 0.6946
# Epoch 50/50
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.1948 - accuracy: 0.9355 - val_loss: 1.9554 - val_accuracy: 0.6944

# %%
#loss
fig, ax = plt.subplots()
ax.plot(history.history['accuracy'], label='Train set accuracy')
ax.plot(history.history['val_accuracy'], label = 'Test set accuracy')
ax.set_xlabel('Epochs')
ax.set_ylabel('Accuracy')
ax.legend()

# %%
fig, ax = plt.subplots()
ax.plot(history.history['loss'])
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
